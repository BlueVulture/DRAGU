# %% [markdown]
# ## Povprečne mesečne plače po občinah
#
# ### Projekt pri podatkovnem rudarjenju
#
# Podatkovno rudarjenje, projekt, `27. 5. 2020`
# **`Domen Ramšak`**

# %% [markdown]
# ### Opis problema
#
# Izbran problem (oziroma zbirka podatkov) je Povprečne mesečne plače po občinah, Slovenija, letno.
#
# Problem zajema povprečne bruto in neto plače po občinah v Sloveniji, z dodatnimi podatki kot so opravljene (oz. plačane) nadure, število oseb, ki so opravljale nadure na mesec, število oseb, ki so prejele zaostala izplačila itd.
#
# Vse vrednosti so povprečne mesečne vrednosti, ki so razdeljena na leta (npr. povp. neto plača na mesec v letu 2015 itd.)
#
# Ti podatki podajo več zanimivih vprašanj, kot npr.:
#   * V katerij regijah Slovenije so plače višje/nižje?
#   * Kako izgleda rast/upad plač skozi leta (posledice recesije?)?
#   * Kje je opravljenih največ nadur, in kje so te najbolje plačane?
#   * Kakšne so vrednosti, če upoštevano/primerjmo inflacijo?
#
# Cilj je seveda analiza, pregled in vizualizacija teh podatkov, ter njihova razdelitev po regijah. Zanima nas tudi razporeditev plač po Sloveniji.

# %% [markdown]
# ### Podatki
#
# V podatkovni datoteki so podane sledeče vrednosti:
#  * Povprečna mesečna bruto plača
#  * Povprečna mesečna neto plača
#  * Indeks povprečne mesečne bruto plače
#  * Indeks povprečne mesečne neto plače
#  * Povprečna plača za plačano naduro
#  * Povprečna mesečna bruto plača za plačano uro
#  * Povprečna mesečna neto plača za plačano uro
#  * Indeks povprečne mesečne bruto plače za plačano uro
#  * Indeks povprečne mesečne neto plače za plačano uro
#  * Zaposlene osebe, ki so prejele zaostala izplačila
#  * Zaposlene osebe z izplačanimi nadurami
#
# Vrednosti so za leta od 2005 do 2019, in so povprečja celotnega leta za posamezne občine v Sloveniji (katerih je 211).
#
# Pred čiščenjem je bilo v podatkih skupaj 700 praznih vrednosti (v podatkih označenih z "-").
#
# Iz podatkov sem odstranil vnose za občine Ankaran in Mirna, saj so tem občinam manjkali podatki za vrsto let (tako je skupaj 209 občin). Odstranila sva tudi leto 2005 za indeks povprečne mesečne plače za plačano uro, saj je to leto bilo popolnoma prazno.
#
# Za potrebe analize sem uporabljal samo neto vrednosti (namesto bruto), saj ponujajo boljšo predstavitev dejanskega denarnega prihodka za posamezno občino.

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib
from matplotlib import pyplot as plt
import geopandas
import warnings
import re
import unidecode
from sklearn import preprocessing
from mpl_toolkits.axes_grid1 import make_axes_locatable

data = pd.read_excel('podatki/0772615.xlsx', index_col=0, header=1)  
print(data.where(data == "-").count().sum())

data = data.drop(["Ankaran", "Mirna"])
data = data.replace(r'-','0').astype(np.float64)
# Out:
# 700
# C:\Users\Domen\.conda\envs\pr_naloge\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
index = np.array([])
for i in data.index:
    if(re.search("/", i)):
#         print(i)
        i = re.sub("/.*", "", i)
#         print(i)
    index = np.append(i, index)
data.index = index

# %%
povpMesecnaPlacaNeto = data.iloc[:, 15:30]
indeksPovpMesecnaPlacaNeto = data.iloc[:, 45:60]
povpPlacaNadure = data.iloc[:, 60:75]
povpMesecnaPlacaNetoUra = data.iloc[:, 90:105]
indeksPovpMesecnaPlacaNetoUra = data.iloc[:, 120:135]
osebeZaostalaPlacila = data.iloc[:, 135:150]
osebeNadure = data.iloc[:, 150:165]

# %%
count = 0
for h in range(2005, 2020):
    povpMesecnaPlacaNeto = povpMesecnaPlacaNeto.rename(columns={povpMesecnaPlacaNeto.columns[count]: h})
    indeksPovpMesecnaPlacaNeto = indeksPovpMesecnaPlacaNeto.rename(columns={indeksPovpMesecnaPlacaNeto.columns[count]: h})
    povpPlacaNadure = povpPlacaNadure.rename(columns={povpPlacaNadure.columns[count]: h})
    povpMesecnaPlacaNetoUra = povpMesecnaPlacaNetoUra.rename(columns={povpMesecnaPlacaNetoUra.columns[count]: h})
    indeksPovpMesecnaPlacaNetoUra = indeksPovpMesecnaPlacaNetoUra.rename(columns={indeksPovpMesecnaPlacaNetoUra.columns[count]: h})
    osebeZaostalaPlacila = osebeZaostalaPlacila.rename(columns={osebeZaostalaPlacila.columns[count]: h})
    osebeNadure = osebeNadure.rename(columns={osebeNadure.columns[count]: h})
    count+=1
    
indeksPovpMesecnaPlacaNetoUra = indeksPovpMesecnaPlacaNetoUra.drop(columns=2005)

# %% [markdown]
# ### Predstavitev podatkov
#
# Pri podatkih lahko opazimo vrsto "SLOVENIJA"; to je povprečje za vse vrednosti, za celotno Slovenijo. S tem lahko zelo lahko najdemo povp. vrednosti za vsak razred. Izrisal sem jih samo za to povprečje, saj bi bilo izris za vseh 211 občin nekoliko preveč.

# %%
# Funkcija za izdelavo subplotov z pandas uporablja depreceted funkcijo in meče opozorila. Ne morem na to vplivati zato sem za 
# ta cell opozorila izklopil.
warnings.filterwarnings('ignore')

fig, axs = plt.subplots(2, 3)
fig.delaxes(axs[1][2])
fig.set_figheight(10)
fig.set_figwidth(15)

povpMesecnaPlacaNeto.loc[["SLOVENIJA"],:].transpose().plot(ax=axs[0,0])
axs[0, 0].set(xlabel="Leta", ylabel="Povp. neto plača v €")
axs[0, 0].legend()
axs[0, 0].set_title("Povp. neto plača skozi čas")

povpPlacaNadure.loc[["SLOVENIJA"],:].transpose().plot(ax=axs[0,1])
axs[0, 1].set(xlabel="Leta", ylabel="Povp. plača nadur v €")
axs[0, 1].legend()
axs[0, 1].set_title("Povp. plača nadur skozi čas")

povpMesecnaPlacaNetoUra.loc[["SLOVENIJA"],:].transpose().plot(ax=axs[0,2])
axs[0, 2].set(xlabel="Leta", ylabel="Povp. neto plača na uro v €")
axs[0, 2].legend()
axs[0, 2].set_title("Povp. neto plača na uro skozi čas")

osebeZaostalaPlacila.loc[["SLOVENIJA"],:].transpose().plot(ax=axs[1,0])
axs[1, 0].set(xlabel="Leta", ylabel="Povp. zaostala plačila")
axs[1, 0].legend()
axs[1, 0].set_title("Povp. zaostala plačila skozi čas")

osebeNadure.loc[["SLOVENIJA"],:].transpose().plot(ax=axs[1, 1])
axs[1, 1].set(xlabel="Leta", ylabel="Povp. oseb z nadurami")
axs[1, 1].legend()
axs[1, 1].set_title("Povp. oseb z nadurami skozi čas")
# Out:
# Text(0.5, 1.0, 'Povp. oseb z nadurami skozi čas')

# %%
# Funkcija za izdelavo subplotov z pandas uporablja depreceted funkcijo in meče opozorila. Ne morem na to vplivati zato sem za 
# ta cell opozorila izklopil. Tule se nazaj vklopijo
warnings.filterwarnings('always')

# %% [markdown]
# Iz podanih grafo se lepo vidi da so skoraj vse metrike upadle/stagnirale v letih od prib. 2008 do prib. 2015, najverjetneje kot posledica finančne krize 2007-2008. Link o krizi: https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308

# %% [markdown]
# #### Povprečna neto plača

# %% [markdown]
# Pri vseh letih je največja plača v občini **Cerklje na Gorenjskem**.

# %%
df = pd.DataFrame(columns=range(2005, 2020))
df.insert(0, "", "")
df = df.set_index("")

for l in range(2005, 2020):
    cache = povpMesecnaPlacaNeto.sort_values(l, ascending=0)
    
    for i in range(0, 3):
        if(cache.iloc[:, 0].index[i] not in df.index):
            df = df.append(cache.iloc[i, :])
    
    
for l in range(2005, 2020):
    cache = povpMesecnaPlacaNeto.sort_values(l, ascending=0)
    
    for i in range(0, len(df.index)):
        if(df.iloc[i, l-2005] not in cache[l].head(3).values):
            df.at[df.iloc[:, 0].index[i], l] = 0

def h_max(s):
    is_max = s == s.max()
    return ['background-color: #FF6200' if v else '' for v in is_max]

def h_max2(s):
    is_max = s == s.nlargest(3).to_numpy()[1]
    return ['background-color: #FD9346' if v else '' for v in is_max]

def h_max3(s):
    is_max = s == s.nlargest(3).to_numpy()[2]
    return ['background-color: #FDB777' if v else '' for v in is_max]

df = df.round(2)
df.style.apply(h_max).apply(h_max2).apply(h_max3).format('{0:,.2f}')
# Out:
# <style  type="text/css" >
#     #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col0 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col1 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col2 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col3 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col4 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col5 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col6 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col7 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col8 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col9 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col10 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col11 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col12 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col13 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col14 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row1_col0 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col0 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col1 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col2 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col3 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col4 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col5 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col6 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col7 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col8 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col9 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col10 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col11 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col12 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col13 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row2_col14 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row3_col1 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row4_col2 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row4_col3 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row4_col5 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row4_col6 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row4_col7 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row5_col4 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col8 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col9 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col10 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col11 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col12 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col13 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row6_col14 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }</style><table id="T_73d64d4c_a046_11ea_9a75_c8d3ffd17689" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2005</th>        <th class="col_heading level0 col1" >2006</th>        <th class="col_heading level0 col2" >2007</th>        <th class="col_heading level0 col3" >2008</th>        <th class="col_heading level0 col4" >2009</th>        <th class="col_heading level0 col5" >2010</th>        <th class="col_heading level0 col6" >2011</th>        <th class="col_heading level0 col7" >2012</th>        <th class="col_heading level0 col8" >2013</th>        <th class="col_heading level0 col9" >2014</th>        <th class="col_heading level0 col10" >2015</th>        <th class="col_heading level0 col11" >2016</th>        <th class="col_heading level0 col12" >2017</th>        <th class="col_heading level0 col13" >2018</th>        <th class="col_heading level0 col14" >2019</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73d64d4c_a046_11ea_9a75_c8d3ffd17689level0_row0" class="row_heading level0 row0" >Veržej</th>
#                         <td id="T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col0" class="data row0 col0" >994.07</td>
#                         <td id="T_73d64d4c_a046_11ea_9a75_c8d3ffd17689row0_col

# %%
povpMesecnaPlacaNeto.loc[["SLOVENIJA", "Cerklje na Gorenjskem"],:]
# Out:
#                          2005    2006    2007    2008    2009    2010    2011  \
# SLOVENIJA              646.23  665.11  701.15  753.22  778.59  818.01  851.58
# Cerklje na Gorenjskem  741.05  771.12  810.35  825.41  861.23  876.38  899.41
#
#                          2012    2013    2014    2015    2016    2017    2018  \
# SLOVENIJA              837.25  854.39  865.64  882.77  886.12  912.50  947.74
# Cerklje na Gorenjskem  921.15  923.85  937.34  900.57  921.78  932.21  952.13
#
#                           2019
# SLOVENIJA               991.52
# Cerklje na Gorenjskem  1009.41

# %%
ax = povpMesecnaPlacaNeto.loc[["SLOVENIJA", "Cerklje na Gorenjskem"],:].transpose().plot()
ax.set_xlabel("Leta")
ax.set_ylabel("Povp. neto plača v €")
# Out:
# Text(0, 0.5, 'Povp. neto plača v €')

# %% [markdown]
# **Cerklje na Gorenjskem** ima večje povp. kot naslednjih 9 občin z največjim povp. v letu 2019, kar je definitivno presenetljivo:

# %%
povpMesecnaPlacaNeto.sort_values(2019, ascending=0).head(10).transpose().plot()
ax = povpMesecnaPlacaNeto.iloc[0, :].plot(color="black")
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %% [markdown]
# #### Povprečna plača za nadure
#
# Največja plača nadur je veliko bolj razpršena kot povp. plača. Spodnja tabela prikazuje največje tri vrednosti za vsako leto. Gradient je sledeč: temno - večja vrednost, svetlo - manjša vrednost.

# %%
df = pd.DataFrame(columns=range(2005, 2020))
df.insert(0, "", "")
df = df.set_index("")

for l in range(2005, 2020):
    cache = povpPlacaNadure.sort_values(l, ascending=0)
    
    for i in range(0, 3):
        if(cache.iloc[:, 0].index[i] not in df.index):
            df = df.append(cache.iloc[i, :])
    
    
for l in range(2005, 2020):
    cache = povpPlacaNadure.sort_values(l, ascending=0)
    
    for i in range(0, len(df.index)):
        if(df.iloc[i, l-2005] not in cache[l].head(3).values):
            df.at[df.iloc[:, 0].index[i], l] = 0

def h_max(s):
    is_max = s == s.max()
    return ['background-color: #FF6200' if v else '' for v in is_max]

def h_max2(s):
    is_max = s == s.nlargest(3).to_numpy()[1]
    return ['background-color: #FD9346' if v else '' for v in is_max]

def h_max3(s):
    is_max = s == s.nlargest(3).to_numpy()[2]
    return ['background-color: #FDB777' if v else '' for v in is_max]

df = df.round(2)
df.style.apply(h_max).apply(h_max2).apply(h_max3).format('{0:,.2f}')
# Out:
# <style  type="text/css" >
#     #T_74692882_a046_11ea_a812_c8d3ffd17689row0_col0 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row1_col0 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row2_col0 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row2_col1 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col1 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col2 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col3 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col4 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col5 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row3_col7 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col1 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col3 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col4 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col6 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col7 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col8 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col10 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col11 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col12 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col13 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row4_col14 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row5_col2 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row5_col4 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row5_col5 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row5_col8 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row6_col2 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col3 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col6 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col7 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col8 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col11 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col12 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row7_col13 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row8_col5 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row9_col6 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row10_col9 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row11_col9 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row12_col9 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row13_col10 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row14_col10 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row15_col11 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row16_col12 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row16_col13 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row17_col14 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_74692882_a046_11ea_a812_c8d3ffd17689row18_col14 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }</style><table id="T_74692882_a046_11ea_a812_c8d3ffd17689" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2005</th>        <th class="col_heading level0 col1" >2006</th>        <th class="col_heading level0 col2" >2007</th>        <th class="col_heading level0 col3" >2008</th>        <th class="col_heading level0 col4" >2009</th>        <th class="col_heading level0 col5" >2010</th>        <th class="col_heading level0 col6" >2011</th>        <th class="col_heading level0 col7" >2012</th>        <th class="col_heading level0 col8" >2013</th>        <th class="col_heading level0 col9" >2014</th>        <th class="col_heading level0 col10" >2015</th>        <th class="col_heading level0 col11" >2016</th>        <th class="col_heading level0 col12" >2017</th>        <th class="col_heading level0 col13" >2018</th>        <th class="col_heading level0 col14" >2019</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74692882_a046_11ea_a812_c8d3ffd17689level0_row0" class="row_heading level0 row0" >Cerkno</th>
#                         <td id="T_74692882_a046_11ea_a812_c8d3ffd17689row0_col0" class="data row0 col0" >21.07</td>
#                         <td id="T_74692882_a046_11ea_a812_c8d3ffd1768

# %% [markdown]
# Največje plače za nadure po letih.

# %%
df = pd.DataFrame(columns=range(2005, 2020))


for l in range(2005, 2020):
    cache = povpPlacaNadure.sort_values(l, ascending=0)
    df.at[0, l] = cache.iloc[:, 0].index[0]
    df.at[1, l] = cache.iloc[0, l-2005]
    
df
# Out:
#      2005               2006   2007    2008  2009             2010   2011  \
# 0  Cerkno  Dolenjske Toplice   Brda  Veržej  Grad  Renče - Vogrsko   Grad
# 1   21.07              13.47  12.37   16.96    22            61.93  19.19
#
#     2012   2013      2014     2015   2016   2017      2018   2019
# 0   Grad   Grad  Juršinci  Velenje   Grad   Grad  Beltinci  Bloke
# 1  20.41  20.07     25.15    25.47  20.09  18.95     20.08  22.04

# %% [markdown]
# Primerjava vseh teh občin čez leta:

# %%
af = pd.DataFrame(columns=range(2005, 2020))
af.insert(0, "", "")
af = af.set_index("")

for v in df.iloc[0,:].values:
    if(v not in af.index):
        af = af.append(povpPlacaNadure.loc[v, :])
        
# af = af.append(povpPlacaNadure.loc["SLOVENIJA", :])
plt.figure()

af.transpose().plot()
ax = povpPlacaNadure.loc["SLOVENIJA", :].transpose().plot(color="black")
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %% [markdown]
# Razkrije da je plača nadur v Kostel-ju leta 2010 osamelec. V primerjavi s številom oseb, katerim so te nadure bile izplačane:

# %%
af = pd.DataFrame(columns=range(2005, 2020))
af.insert(0, "", "")
af = af.set_index("")

for v in df.iloc[0,:].values:
    if(v not in af.index):
        af = af.append(osebeNadure.loc[v, :])
        
# af = af.append(povpPlacaNadure.loc["SLOVENIJA", :])
plt.figure()

af.transpose().plot()
ax = osebeNadure.loc["SLOVENIJA", :].transpose().plot(color="black")
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %% [markdown]
# Pokaže, da število oseb ni abnormalno nizko, kot sva pričakovala, ampak je celo konsistentno z povp. celotne Slovenije.

# %% [markdown]
# #### Zaposlene osebe, ki so prejele zaostala izplačila

# %% [markdown]
# Največ prejetih zaostalih plač se pojavi v Medvodah, sploh v letih od 2012 do 2018.

# %%
df = pd.DataFrame(columns=range(2005, 2020))
df.insert(0, "", "")
df = df.set_index("")

for l in range(2005, 2020):
    cache = osebeZaostalaPlacila.sort_values(l, ascending=0)
    
    for i in range(0, 3):
        if(cache.iloc[:, 0].index[i] not in df.index):
            df = df.append(cache.iloc[i, :])
    
    
for l in range(2005, 2020):
    cache = osebeZaostalaPlacila.sort_values(l, ascending=0)
    
    for i in range(0, len(df.index)):
        if(df.iloc[i, l-2005] not in cache[l].head(3).values):
            df.at[df.iloc[:, 0].index[i], l] = 0

def h_max(s):
    is_max = s == s.max()
    return ['background-color: #FF6200' if v else '' for v in is_max]

def h_max2(s):
    is_max = s == s.nlargest(3).to_numpy()[1]
    return ['background-color: #FD9346' if v else '' for v in is_max]

def h_max3(s):
    is_max = s == s.nlargest(3).to_numpy()[2]
    return ['background-color: #FDB777' if v else '' for v in is_max]

df = df.round(2)
df.style.apply(h_max).apply(h_max2).apply(h_max3).format('{0:,.2f}')
# Out:
# <style  type="text/css" >
#     #T_750daa09_a046_11ea_852d_c8d3ffd17689row0_col0 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row0_col5 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row0_col11 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col0 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col1 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col2 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col3 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col4 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row1_col5 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row2_col0 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row3_col1 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row3_col5 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row4_col1 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row5_col2 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row6_col2 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row7_col3 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row8_col3 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row8_col7 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row8_col8 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row8_col9 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row8_col10 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row9_col4 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row10_col4 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row11_col6 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col6 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col7 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col8 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col9 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col10 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col11 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row12_col12 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row13_col6 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row14_col7 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row15_col8 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row15_col10 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row15_col13 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row15_col14 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row16_col9 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row16_col10 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row17_col11 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row17_col12 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row17_col13 {
#             : ;
#             background-color:  #FD9346;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row17_col14 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row18_col12 {
#             : ;
#             : ;
#             background-color:  #FDB777;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row18_col13 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }    #T_750daa09_a046_11ea_852d_c8d3ffd17689row18_col14 {
#             background-color:  #FF6200;
#             : ;
#             : ;
#         }</style><table id="T_750daa09_a046_11ea_852d_c8d3ffd17689" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2005</th>        <th class="col_heading level0 col1" >2006</th>        <th class="col_heading level0 col2" >2007</th>        <th class="col_heading level0 col3" >2008</th>        <th class="col_heading level0 col4" >2009</th>        <th class="col_heading level0 col5" >2010</th>        <th class="col_heading level0 col6" >2011</th>        <th class="col_heading level0 col7" >2012</th>        <th class="col_heading level0 col8" >2013</th>        <th class="col_heading level0 col9" >2014</th>        <th class="col_heading level0 col10" >2015</th>        <th class="col_heading level0 col11" >2016</th>        <th class="col_heading level0 col12" >2017</th>        <th class="col_heading level0 col13" >2018</th>        <th class="col_heading level0 col14" >2019</th>    </tr>    <tr>        <th class="index_name level0" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_750daa09_a046_11ea_852d_c8d3ffd17689level0_row0" class="row_heading level0 row0" >Polzela</th>
#                         <td id="T

# %%
df = pd.DataFrame(columns=range(2005, 2020))


for l in range(2005, 2020):
    cache = osebeZaostalaPlacila.sort_values(l, ascending=0)
    df.at[0, l] = cache.iloc[:, 0].index[0]
    df.at[1, l] = cache.iloc[0, l-2005]
    
df
# Out:
#       2005     2006        2007        2008       2009        2010       2011  \
# 0  Polzela  Pesnica  Cerkvenjak  Cerkvenjak  Železniki  Cerkvenjak  Rogašovci
# 1     26.4     28.9        32.7        34.2       27.6        37.5       31.6
#
#       2012     2013     2014     2015     2016     2017   2018   2019
# 0  Medvode  Medvode  Medvode  Medvode  Medvode  Medvode  Hodoš  Hodoš
# 1     78.1     76.2     77.2     76.9     80.2       50   33.9   34.7

# %%
af = pd.DataFrame(columns=range(2005, 2020))
af.insert(0, "", "")
af = af.set_index("")

for v in df.iloc[0,:].values:
    if(v not in af.index):
        af = af.append(osebeZaostalaPlacila.loc[v, :])
        
# af = af.append(povpPlacaNadure.loc["SLOVENIJA", :])
plt.figure()

af.transpose().plot()
ax = osebeZaostalaPlacila.loc["SLOVENIJA", :].transpose().plot(color="black")
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %% [markdown]
# ### Delitev podatkov po regijah
#
# Za prikaz podatkov na zemljevidu slovenije sem pridobil shapefile iz https://gadm.org/, ter z pomočjo knjižnice Geopandas zemljevide izrisal.
#
# Za prikaz sem mogel podatke nekoliko prirediti, oz. predprocesirati; imena občin sem mogel spremeniti v primerno obliko (zaradi nekosistentnosti šumnikov in začetnic v bazi za zemljevid sem vse šumnike pretvoril), ter vse vrednosti razdeliti po statističnih regijah.
#
# Vse vrednosti (neto plače, nadure, itd.) sem nato tudi normaliziral, da se graf lepo prikaže.

# %%
# Branje zemljevidov, popravljanje regij

si_regions = geopandas.read_file("shapefiles/gadm36_SVN_1.shp", encoding='utf-8')
si_counties = geopandas.read_file("shapefiles/gadm36_SVN_2.shp", encoding='utf-8')
si_regions = si_regions.drop(["NL_NAME_1", "CC_1", "TYPE_1", "ENGTYPE_1", "HASC_1", "GID_0", "NAME_0", "GID_1"], axis=1)
si_counties = si_counties.drop(["GID_0", "NAME_0", "GID_1", "NL_NAME_1", "GID_2", "NL_NAME_2", "VARNAME_2", "TYPE_2","ENGTYPE_2", "CC_2", "HASC_2"], axis=1)

si_regions.loc[si_regions["NAME_1"] == "Notranjsko-kraška", "NAME_1"] = "Primorsko-notranjska"
si_regions.loc[si_regions["NAME_1"] == "Spodnjeposavska", "NAME_1"] = "Posavska"

si_counties.loc[si_counties["NAME_1"] == "Notranjsko-kraška", "NAME_1"] = "Primorsko-notranjska"
si_counties.loc[si_counties["NAME_1"] == "Spodnjeposavska", "NAME_1"] = "Posavska"
# si_county.NAME_1.unique()

# %%
# Dict vseh regij in njihovih občin

regions = dict()

for region in si_counties.NAME_1.unique():
    regions[region] = si_counties[si_counties["NAME_1"] == region].NAME_2.values
        
# regions

# %%
# Razdeljevanje v posebna arraya

regions_column = np.array([])
counties_column = np.array([])

for region in regions.keys():
    cache = np.array([region])   
    cache = np.repeat(cache, len(regions[region]))
    regions_column = np.append(regions_column, cache)
    counties_column = np.append(counties_column, regions[region])

index = np.array([])
for c in counties_column:
    index = np.append(index, unidecode.unidecode(c))

counties_column = index
    
regions_index = pd.MultiIndex.from_arrays([regions_column, counties_column], names=("region", "county"))
regions_values = pd.DataFrame(columns=range(2005, 2020), index=regions_index)

# %%
# Popravljanje šumnikov in začetnic

regions_povpMesecnaPlacaNeto = regions_values.copy()
regions_povpPlacaNadure = regions_values.copy()
regions_osebeNadure = regions_values.copy()

def fix_index(df):
    index = np.array([])
    for i in df.index:
        index = np.append(index, unidecode.unidecode(i))

    df.index = index

fix_index(povpMesecnaPlacaNeto)
fix_index(povpPlacaNadure)
fix_index(osebeNadure)

c1 = ""

for r in regions:
    for c in regions[r]:
        c = unidecode.unidecode(c)
        c1 = c
        c1 = re.sub("-", " - ", c)
        c1 = re.sub("Vas", "vas", c1)
        c1 = re.sub("Mesto", "mesto", c1)
        c1 = re.sub("Dolina", "dolina", c1)
        c1 = re.sub("Polju", "polju", c1)
        c1 = re.sub("Sveti Andraz v Slovenskih Goricah", "Sveti Andraz v Slov. goricah", c1)
        c1 = re.sub("Sentjur pri Celju", "Sentjur", c1)
        c1 = re.sub("Sveti Jurij", "Sveti Jurij ob Scavnici", c1)
            
        if(c1 in povpMesecnaPlacaNeto.index):
            regions_povpMesecnaPlacaNeto.loc[r, c] = povpMesecnaPlacaNeto.loc[c1]
            regions_povpPlacaNadure.loc[r, c] = povpPlacaNadure.loc[c1]
            regions_osebeNadure.loc[r, c] = osebeNadure.loc[c1]

# %%
regions_povpMesecnaPlacaNeto = regions_povpMesecnaPlacaNeto.astype(float)
r_placa = regions_povpMesecnaPlacaNeto.groupby(level=0).mean()

# %%
fig, ax = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(15)

print(ax.shape)

r_placa.transpose().plot(ax=ax[0])
ax[0].set_xlabel("Leta")
ax[0].set_ylabel("Povp. neto plača v €")
leg = plt.legend( loc = 'upper right')
bb = leg.get_bbox_to_anchor().inverse_transformed(ax[0].transAxes)
xOffset = 0.5
bb.x0 += xOffset
bb.x1 += xOffset
leg.set_bbox_to_anchor(bb, transform = ax[0].transAxes)

povpMesecnaPlacaNeto.loc[["SLOVENIJA"],:].transpose().plot(ax=ax[1])
ax[1].set_xlabel("Leta")
ax[1].set_ylabel("Povp. neto plača v €")
# Out:
# No handles with labels found to put in legend.
# (2,)
# Text(0, 0.5, 'Povp. neto plača v €')

# %% [markdown]
# Vse regije imajo očitno zelo podobno povp. plačo kot vse druge in so konsistente tudi z Slovenskim povprečjem.

# %%
# Normalizacija s pomočjo knjižnice sklearn

def normalize_df(df):
    index = df.index
    x = df.values
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    df = pd.DataFrame(x_scaled, columns=df.columns, index=index)
    return df

regions_povpMesecnaPlacaNeto_normal = normalize_df(regions_povpMesecnaPlacaNeto)
regions_povpPlacaNadure_normal = normalize_df(regions_povpPlacaNadure)
regions_osebeNadure_normal = normalize_df(regions_osebeNadure)

# regions_povpMesecnaPlacaNeto_normal
# regions_povpPlacaNadure_normal
# regions_osebeNadure_normal

# %%
# Prikaz vrednosti za občine

df = regions_povpMesecnaPlacaNeto_normal.groupby(level=0).mean()
df = normalize_df(df)
df.reset_index(inplace=True) 
df= df.drop(["region"], axis=1)

si_regions_pay = si_regions.join(df)

# %%
y = 2005

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_pay.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev plač v letu 2005')

# %%
y = 2019

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_pay.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev plač v letu 2019')

# %% [markdown]
# Na podlagi teh dveh grafov lahko vidimo da so se večje plače nekoliko odmaknile od osrednje slovenije proti severu in vzhodu, vendar bi del tega lahko bilo tudi seljenje ljudi iz teh regij, s čimer posledično zmanjšajo koeficient pri račuanju povprečij.

# %%
# # To se naj zažene samo enkrat
regions_povpMesecnaPlacaNeto_normal.reset_index(inplace=True)  
# regions_povpMesecnaPlacaNeto_normal = regions_povpMesecnaPlacaNeto_normal.drop(["index"], axis=1)
si_counties_pay = si_counties.join(regions_povpMesecnaPlacaNeto_normal)

# %%
# Prikaz vrednosti za občine

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_counties_pay.plot(edgecolor='black', figsize=(20, 20), column=2005, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač v letu 2005")

# plt.show()
# Out:
# Text(0.5, 1.0, 'Razporeditev plač v letu 2005')

# %%
# Prikaz vrednosti za občine

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_counties_pay.plot(edgecolor='black', figsize=(20, 20), column=2019, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač v letu 2019")

# plt.show()
# Out:
# Text(0.5, 1.0, 'Razporeditev plač v letu 2019')

# %%
df = regions_povpPlacaNadure_normal.groupby(level=0).mean()
df = normalize_df(df)
df.reset_index(inplace=True) 
df= df.drop(["region"], axis=1)

si_regions_nad = si_regions.join(df)
# si_regions_nad
# regions_povpPlacaNadure_normal

# %%
y = 2005

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_nad.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač nadur v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev plač nadur v letu 2005')

# %%
y = 2019

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_nad.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev plač nadur v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev plač nadur v letu 2019')

# %% [markdown]
# Podobno kot pri neto plačah, se tudi pri nadurah pojavljajo večje vrednosti na severo-vzhodu, sploh v na Prekmurskem in na Savinjskem.

# %%
df = regions_osebeNadure_normal.groupby(level=0).mean()
df = normalize_df(df)
df.reset_index(inplace=True) 
df= df.drop(["region"], axis=1)

si_regions_os = si_regions.join(df)

# %%
y = 2005

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_os.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev št. oseb z nadurami v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev št. oseb z nadurami v letu 2005')

# %%
y = 2019

fig, ax = plt.subplots(1, 1)
fig.figsize=(20, 20)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)
ax = si_regions_os.plot(edgecolor='black', figsize=(20, 20), column=y, legend=True, cax=cax, ax=ax, cmap="Blues")
ax.figure.set_size_inches(15, 15)
ax.set_aspect(1.5)
ax.set_title("Razporeditev št. oseb z nadurami v letu " + str(y))
# Out:
# Text(0.5, 1.0, 'Razporeditev št. oseb z nadurami v letu 2019')

# %% [markdown]
# Pri številu oseb z nadurami se hitro prikaže velik osamelec v Prekmurski regiji, saj ima povp. izjemno veliko ljudi z nadurami.

# %% [markdown]
# ## Zaključek
#
# Pri nalogi morda nisem mogle raziskati vseh zadanih ciljev, vendar se mi zdi da sem dokaj dobro pokazal sledeče:
# * Vpliv finančne krize 2008 na slovensko ekonomijo (predvsem pri plačah)
# * Razvoj severo-vzhoda Slovenije
# * Plače skozi leta po regijah
